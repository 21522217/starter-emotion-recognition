# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# navigate to working folder
# %cd '/content/drive/MyDrive/UIT/HK1_2023-2024/Project_01/Process'
# Out:
# /content/drive/MyDrive/UIT/HK1_2023-2024/Project_01/Process

# %%
# !pwd
# Out:
# /content/drive/MyDrive/UIT/HK1_2023-2024/Project_01/Process

# %% [markdown]
# THIS IS WHERE THE TRAINING BEGINS

# %%
# import necessary libraries
import os
import cv2
from google.colab import files
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.utils import to_categorical

# %%
# Read the dataset into a pandas dataframe
df = pd.read_csv('./fer2013.csv')

# %%
print(df)
# Out:
#        emotion                                             pixels     Usage
# 0            0  131 133 131 131 132 138 155 150 134 148 141 16...  Training
# 1            0  118 118 142 165 168 160 165 169 167 168 167 16...  Training
# 2            0  83 87 88 89 78 96 108 102 119 128 147 162 157 ...  Training
# 3            0  32 37 45 46 61 67 80 89 89 94 99 107 111 113 1...  Training
# 4            0  245 227 218 226 221 223 240 235 236 231 225 16...  Training
# ...        ...                                                ...       ...
# 35882        5  239 241 240 239 241 238 227 127 124 161 156 15...      Test
# 35883        5  47 45 51 38 31 34 33 70 32 34 26 26 24 33 14 1...      Test
# 35884        5  68 79 89 102 117 125 127 127 128 136 140 138 1...      Test
# 35885        5  228 222 210 194 202 208 209 179 156 143 134 13...      Test
# 35886        5  46 46 41 48 55 55 62 63 39 33 30 44 45 45 58 5...      Test
#
# [35887 rows x 3 columns]

# %%
# Preprocess data function
def preprocess_data(df):
    images = df["pixels"].apply(lambda x: np.array(x.split(" "), dtype=np.float32))
    images = np.array([x.reshape(48, 48, 1) for x in images])
    images /= 255.0
    labels = to_categorical(df["emotion"])
    return images, labels

# data splitting and data preprocessing
train_data = df[df["Usage"] == "Training"]
test_data = df[df["Usage"] == "Test"]
x_train, y_train = preprocess_data(train_data)
x_test, y_test = preprocess_data(test_data)
# Out:
# Training data size: 28709
# Test data size: 7178

# %%
# build model
model = Sequential([
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(7, activation='softmax'),
])

# %%
# compile the model (MUST DO BEFORE TRAINING)
model.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=20, batch_size=128)
# Out:
# Epoch 1/20
# 225/225 [==============================] - 2s 6ms/step - loss: 1.8574 - accuracy: 0.2254
# Epoch 2/20
# 225/225 [==============================] - 1s 6ms/step - loss: 1.8143 - accuracy: 0.2509
# Epoch 3/20
# 225/225 [==============================] - 1s 6ms/step - loss: 1.7946 - accuracy: 0.2641
# Epoch 4/20
# 225/225 [==============================] - 1s 5ms/step - loss: 1.7754 - accuracy: 0.2774
# Epoch 5/20
# 225/225 [==============================] - 1s 5ms/step - loss: 1.7597 - accuracy: 0.2892
# Epoch 6/20
# 225/225 [==============================] - 1s 5ms/step - loss: 1.7429 - accuracy: 0.3013
# Epoch 7/20
# 225/225 [==============================] - 1s 5ms/step - loss: 1.7305 - accuracy: 0.3099
# Epoch 8/20
# 225/225 [==============================] - 1s 5ms/step - loss: 1.7216 - accuracy: 0.3159
# Epoch 9/20
# 225/225 [==============================] - 1s 5ms/step - loss: 1.7126 - accuracy: 0.3205
# Epoch 10/20
# 225/225 [==============================] - 1s 5ms/step - loss: 1.7049 - accuracy: 0.3245
# Epoch 11/20
# 225/225 [==============================] - 1s 5ms/step - loss: 1.6981 - accuracy: 0.3321
# Epoch 12/20
# 225/225 [==============================] - 1s 5ms/step - loss: 1.6912 - accuracy: 0.3337
# Epoch 13/20
# 225/225 [==============================] - 1s 6ms/step - loss: 1.6830 - accuracy: 0.3370
# Epoch 14/20
# 225/225 [==============================] - 1s 6ms/step - loss: 1.6790 - accuracy: 0.3365
# Epoch 15/20
# 225/225 [==============================] - 1s 5ms/step - loss: 1.6794 - accuracy: 0.3368
# Epoch 16/20
# 225/225 [==============================] - 1s 5ms/step - loss: 1.6733 - accuracy: 0.3407
# Epoch 17/20
# 225/225 [==============================] - 1s 5ms/step - loss: 1.6691 - accuracy: 0.3405
# Epoch 18/20
# 225/225 [==============================] - 1s 5ms/step - loss: 1.6645 - accuracy: 0.3436
# Epoch 19/20
# 225/225 [==============================] - 1s 5ms/step - loss: 1.6595 - accuracy: 0.3475
# Epoch 20/20
# 225/225 [==============================] - 1s 5ms/step - loss: 1.6553 - accuracy: 0.3468

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 128)               295040
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 312455 (1.19 MB)
# Trainable params: 312455 (1.19 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Loss: ", test_loss)
print("Test Accuracy: ", test_acc)
# Out:
# 225/225 [==============================] - 0s 1ms/step - loss: 1.6342 - accuracy: 0.3598
# Loss:  1.6342006921768188
# Test Accuracy:  0.3598495423793793

# %%
model_name = 'emotion_model_v03'
# save model
model.save(f"{model_name}.h5")
# Download the model
files.download(f"{model_name}.h5")
