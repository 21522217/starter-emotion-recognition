# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# navigate to working folder
# %cd '/content/drive/MyDrive/UIT/HK1_2023-2024/Project_01/Process'
# Out:
# /content/drive/MyDrive/UIT/HK1_2023-2024/Project_01/Process

# %%
# !pwd
# Out:
# /content/drive/MyDrive/UIT/HK1_2023-2024/Project_01/Process

# %% [markdown]
# THIS IS WHERE THE TRAINING BEGINS

# %%
# import necessary libraries and define constants
import os
import cv2
from google.colab import files
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.utils import to_categorical
from keras.callbacks import TensorBoard

# %%
# Read the dataset into a pandas dataframe
df = pd.read_csv('./fer2013.csv')

# %%
print(df)
# Out:
#        emotion                                             pixels     Usage
# 0            0  131 133 131 131 132 138 155 150 134 148 141 16...  Training
# 1            0  118 118 142 165 168 160 165 169 167 168 167 16...  Training
# 2            0  83 87 88 89 78 96 108 102 119 128 147 162 157 ...  Training
# 3            0  32 37 45 46 61 67 80 89 89 94 99 107 111 113 1...  Training
# 4            0  245 227 218 226 221 223 240 235 236 231 225 16...  Training
# ...        ...                                                ...       ...
# 35882        5  239 241 240 239 241 238 227 127 124 161 156 15...      Test
# 35883        5  47 45 51 38 31 34 33 70 32 34 26 26 24 33 14 1...      Test
# 35884        5  68 79 89 102 117 125 127 127 128 136 140 138 1...      Test
# 35885        5  228 222 210 194 202 208 209 179 156 143 134 13...      Test
# 35886        5  46 46 41 48 55 55 62 63 39 33 30 44 45 45 58 5...      Test
#
# [35887 rows x 3 columns]

# %%
# Preprocess data function
def preprocess_data(df):
    images = df["pixels"].apply(lambda x: np.array(x.split(" "), dtype=np.float32))
    images = np.array([x.reshape(48, 48, 1) for x in images])
    images /= 255.0
    labels = to_categorical(df["emotion"])
    return images, labels

# data splitting and data preprocessing
train_data = df[df["Usage"] == "Training"]
test_data = df[df["Usage"] == "Test"]

x_train, y_train = preprocess_data(train_data)
x_test, y_test = preprocess_data(test_data)

# %%
# build model
model = Sequential([
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(7, activation='softmax'),
])

# %%
# compile the model (MUST DO BEFORE TRAINING)
model.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=50, batch_size=128)
# Out:
# Epoch 1/50
# 225/225 [==============================] - 6s 5ms/step - loss: 1.8481 - accuracy: 0.2305
# Epoch 2/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.8119 - accuracy: 0.2466
# Epoch 3/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.7899 - accuracy: 0.2655
# Epoch 4/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7694 - accuracy: 0.2783
# Epoch 5/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7553 - accuracy: 0.2900
# Epoch 6/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7371 - accuracy: 0.3039
# Epoch 7/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7257 - accuracy: 0.3116
# Epoch 8/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7131 - accuracy: 0.3179
# Epoch 9/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7055 - accuracy: 0.3221
# Epoch 10/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6987 - accuracy: 0.3256
# Epoch 11/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6874 - accuracy: 0.3363
# Epoch 12/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6850 - accuracy: 0.3366
# Epoch 13/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6773 - accuracy: 0.3391
# Epoch 14/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6718 - accuracy: 0.3413
# Epoch 15/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.6702 - accuracy: 0.3434
# Epoch 16/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.6637 - accuracy: 0.3455
# Epoch 17/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.6576 - accuracy: 0.3476
# Epoch 18/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6561 - accuracy: 0.3497
# Epoch 19/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6509 - accuracy: 0.3554
# Epoch 20/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6462 - accuracy: 0.3558
# Epoch 21/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6441 - accuracy: 0.3540
# Epoch 22/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6402 - accuracy: 0.3580
# Epoch 23/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6345 - accuracy: 0.3597
# Epoch 24/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6322 - accuracy: 0.3607
# Epoch 25/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6310 - accuracy: 0.3617
# Epoch 26/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6276 - accuracy: 0.3629
# Epoch 27/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6262 - accuracy: 0.3639
# Epoch 28/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6200 - accuracy: 0.3648
# Epoch 29/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6178 - accuracy: 0.3695
# Epoch 30/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.6171 - accuracy: 0.3692
# Epoch 31/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.6133 - accuracy: 0.3701
# Epoch 32/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.6090 - accuracy: 0.3716
# Epoch 33/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.6044 - accuracy: 0.3732
# Epoch 34/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6024 - accuracy: 0.3760
# Epoch 35/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6018 - accuracy: 0.3752
# Epoch 36/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5956 - accuracy: 0.3790
# Epoch 37/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5970 - accuracy: 0.3747
# Epoch 38/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5899 - accuracy: 0.3801
# Epoch 39/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5936 - accuracy: 0.3817
# Epoch 40/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5916 - accuracy: 0.3803
# Epoch 41/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5857 - accuracy: 0.3836
# Epoch 42/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5829 - accuracy: 0.3833
# Epoch 43/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5827 - accuracy: 0.3856
# Epoch 44/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5790 - accuracy: 0.3849
# Epoch 45/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.5776 - accuracy: 0.3895
# Epoch 46/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.5728 - accuracy: 0.3901
# Epoch 47/50
# 225/225 [==============================] - 1s 6ms/step - loss: 1.5708 - accuracy: 0.3902
# Epoch 48/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.5696 - accuracy: 0.3883
# Epoch 49/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5665 - accuracy: 0.3952
# Epoch 50/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5649 - accuracy: 0.3953

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 128)               295040
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 312455 (1.19 MB)
# Trainable params: 312455 (1.19 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Loss: ", test_loss)
print("Test Accuracy: ", test_acc)
# Out:
# 225/225 [==============================] - 1s 3ms/step - loss: 1.5633 - accuracy: 0.4009
# Loss:  1.563315510749817
# Test Accuracy:  0.40094733238220215

# %%
model_name = 'emotion_model_v06'
# save model
model.save(f"{model_name}.h5")
# Download the model
files.download(f"{model_name}.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
