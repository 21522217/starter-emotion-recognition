# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# navigate to working folder
# %cd '/content/drive/MyDrive/UIT/HK1_2023-2024/Project_01/Process'
# Out:
# /content/drive/MyDrive/UIT/HK1_2023-2024/Project_01/Process

# %%
# !pwd
# Out:
# /content/drive/MyDrive/UIT/HK1_2023-2024/Project_01/Process

# %% [markdown]
# THIS IS WHERE THE TRAINING BEGINS

# %%
# import necessary libraries and define constants
import os
import cv2
from google.colab import files
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.utils import to_categorical
from keras.optimizers import RMSprop, SGD

# %%
# Read the dataset into a pandas dataframe
df = pd.read_csv('./fer2013.csv')

# %%
print(df)
# Out:
#        emotion                                             pixels     Usage
# 0            0  131 133 131 131 132 138 155 150 134 148 141 16...  Training
# 1            0  118 118 142 165 168 160 165 169 167 168 167 16...  Training
# 2            0  83 87 88 89 78 96 108 102 119 128 147 162 157 ...  Training
# 3            0  32 37 45 46 61 67 80 89 89 94 99 107 111 113 1...  Training
# 4            0  245 227 218 226 221 223 240 235 236 231 225 16...  Training
# ...        ...                                                ...       ...
# 35882        5  239 241 240 239 241 238 227 127 124 161 156 15...      Test
# 35883        5  47 45 51 38 31 34 33 70 32 34 26 26 24 33 14 1...      Test
# 35884        5  68 79 89 102 117 125 127 127 128 136 140 138 1...      Test
# 35885        5  228 222 210 194 202 208 209 179 156 143 134 13...      Test
# 35886        5  46 46 41 48 55 55 62 63 39 33 30 44 45 45 58 5...      Test
#
# [35887 rows x 3 columns]

# %%
# Preprocess data function
def preprocess_data(df):
    images = df["pixels"].apply(lambda x: np.array(x.split(" "), dtype=np.float32))
    images = np.array([x.reshape(48, 48, 1) for x in images])
    images /= 255.0
    labels = to_categorical(df["emotion"])
    return images, labels

# data splitting and data preprocessing
train_data = df[df["Usage"] == "Training"]
test_data = df[df["Usage"] == "Test"]

x_train, y_train = preprocess_data(train_data)
x_test, y_test = preprocess_data(test_data)

# %%
# build model
model = Sequential([
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(7, activation='softmax'),
])

# %%
# compile the model (MUST DO BEFORE TRAINING)
model.compile(optimizer=SGD(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=50, batch_size=128)
# Out:
# Epoch 1/50
# 225/225 [==============================] - 2s 4ms/step - loss: 1.5611 - accuracy: 0.3932
# Epoch 2/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5535 - accuracy: 0.3993
# Epoch 3/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5548 - accuracy: 0.3987
# Epoch 4/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5498 - accuracy: 0.4016
# Epoch 5/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5490 - accuracy: 0.4005
# Epoch 6/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.5524 - accuracy: 0.4014
# Epoch 7/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.5494 - accuracy: 0.4006
# Epoch 8/50
# 225/225 [==============================] - 1s 6ms/step - loss: 1.5481 - accuracy: 0.3992
# Epoch 9/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.5507 - accuracy: 0.3988
# Epoch 10/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5493 - accuracy: 0.4026
# Epoch 11/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5512 - accuracy: 0.3989
# Epoch 12/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5481 - accuracy: 0.4009
# Epoch 13/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5490 - accuracy: 0.4010
# Epoch 14/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5481 - accuracy: 0.4047
# Epoch 15/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5454 - accuracy: 0.4017
# Epoch 16/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5436 - accuracy: 0.4039
# Epoch 17/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5479 - accuracy: 0.4008
# Epoch 18/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5466 - accuracy: 0.4006
# Epoch 19/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5471 - accuracy: 0.3996
# Epoch 20/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5466 - accuracy: 0.4019
# Epoch 21/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.5446 - accuracy: 0.4006
# Epoch 22/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.5460 - accuracy: 0.4048
# Epoch 23/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.5406 - accuracy: 0.4046
# Epoch 24/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.5469 - accuracy: 0.4005
# Epoch 25/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5460 - accuracy: 0.4011
# Epoch 26/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5423 - accuracy: 0.4025
# Epoch 27/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5429 - accuracy: 0.4011
# Epoch 28/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5431 - accuracy: 0.4002
# Epoch 29/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5427 - accuracy: 0.4036
# Epoch 30/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5439 - accuracy: 0.4048
# Epoch 31/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5425 - accuracy: 0.4066
# Epoch 32/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5405 - accuracy: 0.4017
# Epoch 33/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5439 - accuracy: 0.4046
# Epoch 34/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5435 - accuracy: 0.4016
# Epoch 35/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5413 - accuracy: 0.4040
# Epoch 36/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.5419 - accuracy: 0.4055
# Epoch 37/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.5390 - accuracy: 0.4084
# Epoch 38/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.5373 - accuracy: 0.4050
# Epoch 39/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.5408 - accuracy: 0.4025
# Epoch 40/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5394 - accuracy: 0.4041
# Epoch 41/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5421 - accuracy: 0.3988
# Epoch 42/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5406 - accuracy: 0.4022
# Epoch 43/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5385 - accuracy: 0.4036
# Epoch 44/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5411 - accuracy: 0.4051
# Epoch 45/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5362 - accuracy: 0.4045
# Epoch 46/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5402 - accuracy: 0.4055
# Epoch 47/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5375 - accuracy: 0.4061
# Epoch 48/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5394 - accuracy: 0.4027
# Epoch 49/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5383 - accuracy: 0.4044
# Epoch 50/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.5377 - accuracy: 0.4071

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 128)               295040
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 312455 (1.19 MB)
# Trainable params: 312455 (1.19 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Loss: ", test_loss)
print("Test Accuracy: ", test_acc)
# Out:
# 225/225 [==============================] - 1s 4ms/step - loss: 1.5408 - accuracy: 0.4028
# Loss:  1.540826439857483
# Test Accuracy:  0.4027584195137024

# %%
model_name = 'emotion_model_v07'
# save model
model.save(f"{model_name}.h5")
# Download the model
files.download(f"{model_name}.h5")
