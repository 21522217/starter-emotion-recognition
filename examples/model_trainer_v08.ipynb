# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# navigate to working folder
# %cd '/content/drive/MyDrive/UIT/HK1_2023-2024/Project_01/Process'
# Out:
# /content/drive/MyDrive/UIT/HK1_2023-2024/Project_01/Process

# %%
# !pwd
# Out:
# /content/drive/MyDrive/UIT/HK1_2023-2024/Project_01/Process

# %% [markdown]
# THIS IS WHERE THE TRAINING BEGINS

# %%
# import necessary libraries
import os
import cv2
from google.colab import files
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.utils import to_categorical
from keras.optimizers import SGD

# %%
# Read the dataset into a pandas dataframe
df = pd.read_csv('./fer2013.csv')

# %%
print(df)
# Out:
#        emotion                                             pixels     Usage
# 0            0  131 133 131 131 132 138 155 150 134 148 141 16...  Training
# 1            0  118 118 142 165 168 160 165 169 167 168 167 16...  Training
# 2            0  83 87 88 89 78 96 108 102 119 128 147 162 157 ...  Training
# 3            0  32 37 45 46 61 67 80 89 89 94 99 107 111 113 1...  Training
# 4            0  245 227 218 226 221 223 240 235 236 231 225 16...  Training
# ...        ...                                                ...       ...
# 35882        5  239 241 240 239 241 238 227 127 124 161 156 15...      Test
# 35883        5  47 45 51 38 31 34 33 70 32 34 26 26 24 33 14 1...      Test
# 35884        5  68 79 89 102 117 125 127 127 128 136 140 138 1...      Test
# 35885        5  228 222 210 194 202 208 209 179 156 143 134 13...      Test
# 35886        5  46 46 41 48 55 55 62 63 39 33 30 44 45 45 58 5...      Test
#
# [35887 rows x 3 columns]

# %%
# Preprocess data function
def preprocess_data(df):
    images = df["pixels"].apply(lambda x: np.array(x.split(" "), dtype=np.float32))
    images = np.array([x.reshape(48, 48, 1) for x in images])
    images /= 255.0
    labels = to_categorical(df["emotion"])
    return images, labels

# data splitting and data preprocessing
train_data = df[df["Usage"] == "Training"]
test_data = df[df["Usage"] == "Test"]
x_train, y_train = preprocess_data(train_data)
x_test, y_test = preprocess_data(test_data)

# %%
# model settings
model = Sequential([
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.3),
    Dense(512, activation='relu'),
    Dropout(0.3),
    Dense(7, activation='softmax'),
])

# %%
# compile the model (MUST DO BEFORE TRAINING)
model.compile(optimizer=SGD(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=50, batch_size=128)
# Out:
# Epoch 1/50
# 225/225 [==============================] - 6s 4ms/step - loss: 1.9118 - accuracy: 0.2039
# Epoch 2/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.8550 - accuracy: 0.2256
# Epoch 3/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.8352 - accuracy: 0.2379
# Epoch 4/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.8223 - accuracy: 0.2407
# Epoch 5/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.8129 - accuracy: 0.2480
# Epoch 6/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.8112 - accuracy: 0.2492
# Epoch 7/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.8037 - accuracy: 0.2571
# Epoch 8/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7980 - accuracy: 0.2595
# Epoch 9/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7923 - accuracy: 0.2647
# Epoch 10/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7882 - accuracy: 0.2659
# Epoch 11/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7852 - accuracy: 0.2692
# Epoch 12/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.7792 - accuracy: 0.2704
# Epoch 13/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.7772 - accuracy: 0.2747
# Epoch 14/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.7747 - accuracy: 0.2764
# Epoch 15/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.7702 - accuracy: 0.2795
# Epoch 16/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7689 - accuracy: 0.2803
# Epoch 17/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7658 - accuracy: 0.2843
# Epoch 18/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7624 - accuracy: 0.2820
# Epoch 19/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7576 - accuracy: 0.2908
# Epoch 20/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7570 - accuracy: 0.2907
# Epoch 21/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7524 - accuracy: 0.2907
# Epoch 22/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7484 - accuracy: 0.2960
# Epoch 23/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7480 - accuracy: 0.2963
# Epoch 24/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7471 - accuracy: 0.2985
# Epoch 25/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7416 - accuracy: 0.3001
# Epoch 26/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.7397 - accuracy: 0.3040
# Epoch 27/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.7389 - accuracy: 0.3023
# Epoch 28/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.7347 - accuracy: 0.3063
# Epoch 29/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.7346 - accuracy: 0.3071
# Epoch 30/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7291 - accuracy: 0.3129
# Epoch 31/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7288 - accuracy: 0.3137
# Epoch 32/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7266 - accuracy: 0.3124
# Epoch 33/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7226 - accuracy: 0.3181
# Epoch 34/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7207 - accuracy: 0.3170
# Epoch 35/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7189 - accuracy: 0.3149
# Epoch 36/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7149 - accuracy: 0.3236
# Epoch 37/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7150 - accuracy: 0.3199
# Epoch 38/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7128 - accuracy: 0.3226
# Epoch 39/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7112 - accuracy: 0.3199
# Epoch 40/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7070 - accuracy: 0.3257
# Epoch 41/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.7057 - accuracy: 0.3267
# Epoch 42/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.7038 - accuracy: 0.3247
# Epoch 43/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.7013 - accuracy: 0.3305
# Epoch 44/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.7007 - accuracy: 0.3315
# Epoch 45/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6971 - accuracy: 0.3289
# Epoch 46/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6969 - accuracy: 0.3320
# Epoch 47/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6936 - accuracy: 0.3326
# Epoch 48/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6927 - accuracy: 0.3340
# Epoch 49/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6941 - accuracy: 0.3347
# Epoch 50/50
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6900 - accuracy: 0.3363

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 1446407 (5.52 MB)
# Trainable params: 1446407 (5.52 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Loss: ", test_loss)
print("Test Accuracy: ", test_acc)
# Out:
# 225/225 [==============================] - 1s 4ms/step - loss: 1.6660 - accuracy: 0.3534
# Loss:  1.6659975051879883
# Test Accuracy:  0.353441059589386

# %%
model_name = 'emotion_model_v08'
# save model
model.save(f"{model_name}.h5")
# Download the model
files.download(f"{model_name}.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
