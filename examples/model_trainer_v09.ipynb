# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# navigate to working folder
# %cd '/content/drive/MyDrive/UIT/HK1_2023-2024/Project_01/Process'
# Out:
# /content/drive/MyDrive/UIT/HK1_2023-2024/Project_01/Process

# %%
# !pwd
# Out:
# /content/drive/MyDrive/UIT/HK1_2023-2024/Project_01/Process

# %% [markdown]
# THIS IS WHERE THE TRAINING BEGINS

# %%
# import necessary libraries
import os
import cv2
from google.colab import files
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.utils import to_categorical
from keras.optimizers import SGD

# %%
# Read the dataset into a pandas dataframe
df = pd.read_csv('./fer2013.csv')

# %%
print(df)
# Out:
#        emotion                                             pixels     Usage
# 0            0  131 133 131 131 132 138 155 150 134 148 141 16...  Training
# 1            0  118 118 142 165 168 160 165 169 167 168 167 16...  Training
# 2            0  83 87 88 89 78 96 108 102 119 128 147 162 157 ...  Training
# 3            0  32 37 45 46 61 67 80 89 89 94 99 107 111 113 1...  Training
# 4            0  245 227 218 226 221 223 240 235 236 231 225 16...  Training
# ...        ...                                                ...       ...
# 35882        5  239 241 240 239 241 238 227 127 124 161 156 15...      Test
# 35883        5  47 45 51 38 31 34 33 70 32 34 26 26 24 33 14 1...      Test
# 35884        5  68 79 89 102 117 125 127 127 128 136 140 138 1...      Test
# 35885        5  228 222 210 194 202 208 209 179 156 143 134 13...      Test
# 35886        5  46 46 41 48 55 55 62 63 39 33 30 44 45 45 58 5...      Test
#
# [35887 rows x 3 columns]

# %%
# Preprocess data function
def preprocess_data(df):
    images = df["pixels"].apply(lambda x: np.array(x.split(" "), dtype=np.float32))
    images = np.array([x.reshape(48, 48, 1) for x in images])
    images /= 255.0
    labels = to_categorical(df["emotion"])
    return images, labels

# data splitting and data preprocessing
train_data = df[df["Usage"] == "Training"]
test_data = df[df["Usage"] == "Test"]
x_train, y_train = preprocess_data(train_data)
x_test, y_test = preprocess_data(test_data)

# %%
# model settings
model = Sequential([
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(7, activation='softmax'),
])

# %%
# compile the model (MUST DO BEFORE TRAINING)
model.compile(optimizer=SGD(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=50, batch_size=256)
# Out:
# Epoch 1/50
# 113/113 [==============================] - 2s 7ms/step - loss: 1.9548 - accuracy: 0.1754
# Epoch 2/50
# 113/113 [==============================] - 1s 7ms/step - loss: 1.8846 - accuracy: 0.2097
# Epoch 3/50
# 113/113 [==============================] - 1s 7ms/step - loss: 1.8705 - accuracy: 0.2174
# Epoch 4/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.8629 - accuracy: 0.2225
# Epoch 5/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.8552 - accuracy: 0.2276
# Epoch 6/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.8526 - accuracy: 0.2274
# Epoch 7/50
# 113/113 [==============================] - 1s 4ms/step - loss: 1.8462 - accuracy: 0.2324
# Epoch 8/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.8440 - accuracy: 0.2319
# Epoch 9/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.8403 - accuracy: 0.2358
# Epoch 10/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.8414 - accuracy: 0.2357
# Epoch 11/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.8382 - accuracy: 0.2370
# Epoch 12/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.8352 - accuracy: 0.2387
# Epoch 13/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.8318 - accuracy: 0.2415
# Epoch 14/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.8285 - accuracy: 0.2426
# Epoch 15/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.8303 - accuracy: 0.2395
# Epoch 16/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.8255 - accuracy: 0.2449
# Epoch 17/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.8258 - accuracy: 0.2430
# Epoch 18/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.8239 - accuracy: 0.2478
# Epoch 19/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.8197 - accuracy: 0.2482
# Epoch 20/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.8185 - accuracy: 0.2473
# Epoch 21/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.8171 - accuracy: 0.2499
# Epoch 22/50
# 113/113 [==============================] - 1s 6ms/step - loss: 1.8164 - accuracy: 0.2520
# Epoch 23/50
# 113/113 [==============================] - 1s 6ms/step - loss: 1.8153 - accuracy: 0.2488
# Epoch 24/50
# 113/113 [==============================] - 1s 6ms/step - loss: 1.8116 - accuracy: 0.2511
# Epoch 25/50
# 113/113 [==============================] - 1s 6ms/step - loss: 1.8074 - accuracy: 0.2556
# Epoch 26/50
# 113/113 [==============================] - 1s 6ms/step - loss: 1.8074 - accuracy: 0.2559
# Epoch 27/50
# 113/113 [==============================] - 1s 7ms/step - loss: 1.8085 - accuracy: 0.2557
# Epoch 28/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.8090 - accuracy: 0.2543
# Epoch 29/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.8044 - accuracy: 0.2590
# Epoch 30/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.8008 - accuracy: 0.2597
# Epoch 31/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.8008 - accuracy: 0.2601
# Epoch 32/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.8029 - accuracy: 0.2602
# Epoch 33/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.8005 - accuracy: 0.2599
# Epoch 34/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.7958 - accuracy: 0.2633
# Epoch 35/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.7936 - accuracy: 0.2615
# Epoch 36/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.7946 - accuracy: 0.2638
# Epoch 37/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.7906 - accuracy: 0.2666
# Epoch 38/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.7915 - accuracy: 0.2656
# Epoch 39/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.7905 - accuracy: 0.2656
# Epoch 40/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.7927 - accuracy: 0.2662
# Epoch 41/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.7872 - accuracy: 0.2720
# Epoch 42/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.7859 - accuracy: 0.2661
# Epoch 43/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.7850 - accuracy: 0.2705
# Epoch 44/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.7842 - accuracy: 0.2693
# Epoch 45/50
# 113/113 [==============================] - 1s 5ms/step - loss: 1.7842 - accuracy: 0.2744
# Epoch 46/50
# 113/113 [==============================] - 1s 6ms/step - loss: 1.7818 - accuracy: 0.2730
# Epoch 47/50
# 113/113 [==============================] - 1s 6ms/step - loss: 1.7810 - accuracy: 0.2740
# Epoch 48/50
# 113/113 [==============================] - 1s 6ms/step - loss: 1.7796 - accuracy: 0.2736
# Epoch 49/50
# 113/113 [==============================] - 1s 7ms/step - loss: 1.7794 - accuracy: 0.2756
# Epoch 50/50
# 113/113 [==============================] - 1s 6ms/step - loss: 1.7782 - accuracy: 0.2784

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 2304)              0
#
#  dense_3 (Dense)             (None, 128)               295040
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 312455 (1.19 MB)
# Trainable params: 312455 (1.19 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Loss: ", test_loss)
print("Test Accuracy: ", test_acc)
# Out:
# 225/225 [==============================] - 1s 4ms/step - loss: 1.7526 - accuracy: 0.2843
# Loss:  1.7525557279586792
# Test Accuracy:  0.284341037273407

# %%
model_name = 'emotion_model_v09'
# save model
model.save(f"{model_name}.h5")
# Download the model
files.download(f"{model_name}.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
